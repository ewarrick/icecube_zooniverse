# %% [markdown]
# # The Problem with Crossmatching #
# Elizabeth Warrick
#
# **Disclaimer: in future versions we hope to incorporate truth values into the Zooniverse subject data manifest.**

# %% [markdown]
# #### Description ####
# I am attempting to crossmatch the truth classifications of the monte carlo events with the events that have already been classified by Beta testers. Initialy, I thought this would be a simple task of making a mask to select events from the truth value table that have been classified by users in the beta test, then save those as a new key-value pair and add it to the beta classifications catalogue.
#
# The current truth values are not necessasrily correct as they were determined using the old version of the mc label script that was made for a prior version of MC events and was therefore adapted to this version (albeit, still with its problems). Work is being done to implement the new one which is also having problems similar to the older classifier used here.
#
# * Old MC Labeler: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/scripts_ver3/mc_truth.py
#
# * "New" MC Labeler: /home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/scripts_ver3/mc_labeler.py

# %% [markdown]
# ### Imports ###

# %%
import tables
from tables import *
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from icecube import dataclasses, dataio, icetray, MuonGun
from icecube.icetray import I3Units
import icecube.MuonGun
import numpy as np
import h5py

# %% [markdown]
# For understanding the truth labels, here is their corresponding type from the old mc labeler script:
#
# {0: 'Skimming',
#           1: 'Starting Cascade',
#           2: 'Through-Going Track',
#           3: 'Starting Track',
#           4: 'Stopping Track',
#           5: 'Double-Bang',
#           6: 'Stopping Tau',
#           7: 'Glashow Hadronic Cascade',
#           8: 'Glashow Track',
#           9: 'Glashow Tau',
#           11: 'Passing Track',
#           21: 'Several Muons',
#           22: 'Through-Going Bundle',
#           23: 'Stopping Bundle',
#           100: 'Unclassified',
#           101: 'Unclassified'}

# %%
# Run this cell when finished using this notebook to close any opened hdf files. 
#format: variable_name.close()
numu_21971_493_hdf.close()

# %% [markdown]
# ### Beta Data ###
#
# Problems:
# * Repeated events caused by using two different subruns (21971_000 and 21971_493) that had overlapping event IDs -- solved by splitting up user classifications by subject ID.
#     - If the zooniverse ID starts with a 7, then it is from Run 21971_493.
#     * If the zooniverse ID starts with an 8, then it is from Run 21971_000.
# * Some of the repeated events had different truth values.
#     * This is resolved by splitting by subruns since there are sometimes TWO different events that just happen to have the same event ID.

# %%
beta1 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/plots_ver3/data_agg/classifications_counts_beta1.csv'
beta1_df = pd.read_csv(beta1)
b_new = beta1_df.rename(columns={'Unnamed: 0':'Zooniverse_ID'})

# %%
beta_run21971_493 = b_new[b_new['Zooniverse_ID']< 80000000]
beta_run21971_000 = b_new[b_new['Zooniverse_ID']> 80000000]

# %%
beta_unique_21971_493, beta_counts_21971_493 = np.unique(beta_run21971_493['Event'][:], return_counts = True)
beta_unique_21971_000, beta_counts_21971_000 = np.unique(beta_run21971_000['Event'][:], return_counts = True)

if (len(beta_run21971_493) - len(beta_unique_21971_493) == 0):
    print("There are no repeat events in Run21971_493.")
else:
    print("There are repeated events in Run21971_493.")
    
if (len(beta_run21971_000) - len(beta_unique_21971_000) == 0):
    print("There are no repeat events in Run21971_000.")
else:
    print("There are repeated events in Run21971_000.")
# Out:
# There are no repeat events in Run21971_493.
# There are no repeat events in Run21971_000.

# %% [markdown]
# Therefore, by seperating the beta data sub-runs by Zooniverse ID I have made two unique dataframes of userclassifications for each sub-run.

# %% [markdown]
# ### Truth Classifications of MC Events###
#
# I3 File uses the **InIceDSTPulse** pulse series
#
# Problems:
# * Initially looked through the truth classifications of the two sub-runs at the same time. -- I saw repeated event IDs each with their own truth values.
#     * Issue should be resolved by keeping the two sub-runs sperate and by seperating beta classifications by Zooniverse ID (assigned based on time of subject upload to Zooniverse website).
# * Some of the events have recieved multiple truth values within eachi3 file that has associated truth values.
#     * When I look through steamshovel, I sometimes can't find those events with multiple truths. --WHere did those come from? Perhaps a coding error?
#     * Are there events with multipe truth values that have also been classified in the bta test?
#     * If not, can we ignore the repeated events?
#     * Are the multiple truth values a result of inability to handle coincident events?
#     * Do the events with multiple truths have the same truths or different?
#     * Could I be rewriting the truth values in my code?
#
# Current Plan:
#
# I will repeat filtering to get truth values on one of the i3 files (Run21971_493) and see if it has multiple truths or repeated events. If the i3 file does have repeated events/more than one truth per event, then I need to look back at the old truthlabeler script (or else move on and focus on the new one). If the i3 file does not, then it was likely a coding issue on my end.
#
# **Note: I used the same GCD as I did previously in my other tests. I am unsure how to determine if this is a GCD issue.**
#
# **GCD location is '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/i3_files/GeoCalibDetectorStatus_2012.56063_V1.i3.gz'**

# %%
#Open the i3 file's hdf table.

#Note that this file is a remake of the one I have been using. 

#Path to the i3 file hdf.
numu21971_493 = '/home/icecube/Desktop/eliz_zooniverse/icecubezooniverseproj_ver3/plots_ver3/data_agg/\
Crossmatch_Investigation/truthlabels_oldver_classifier_DST_IC86.2020_NuMu.021971.000493.i3.bz2.hd5'
numu_21971_493_hdf = h5py.File(numu21971_493, "r+") #open hdf

#store relavent arrays from i3 hdf as variables for easy access. 
event_ids = numu_21971_493_hdf['I3EventHeader']['Event'][:] #MC event IDs. 
event_truths = numu_21971_493_hdf['classification_truth_id']['value'][:] #MC truth values from mc_truth.py.

# %%
#Checking some stats on the i3 file... 
print("Number of Events in the I3 file: ", len(event_ids)) #prints total number of events. 

print("Number of Truth Classifications in the I3 File: ", len(event_truths)) #prints total number of truth values.

print("Number of unique Event IDs: ", len(np.unique(event_ids))) # prints number of unique event IDs. 

print(f'There are {len(event_ids) - len(np.unique(event_ids))}\
 repeated events in the I3 File for Run21971_493') #prints number of unique event IDs.
# Out:
# Number of Events in the I3 file:  8545
# Number of Truth Classifications in the I3 File:  8545
# Number of unique Event IDs:  8255
# There are 290 repeated events in the I3 File for Run21971_493

# %% [markdown]
# There is a problem because we initially expected there to be an equal number of unique events compared to the toal number of events in the i3 file and the hdf table. To investigate where the repated events come from, lets get a list of which events are repated and confirm that the list matches our above calculations.

# %%
#Based off of a code snippet I found on StackOverflow:

'''
I intialize emtpy dictionary "count" and empty lists "triple" (for events with more than 2 truth values) 
and "double" (for events with 2 truth values).
'''

count = {}
triple = []
double = []
duplicates = []

for i in event_ids:
    if not i in count:
        count[i] = 1
    else:
        count[i] += 1
        if count[i] > 2:
            triple.append(i)
        if count[i] <=2 & count[i] > 1:
            double.append(i)
        if count[i] > 1:
            duplicates.append(i)

print("Number of events with more than 2 truth values: ", len(triple), "with event ID: ", triple)
print("The event: ", triple, "has ", count[triple[0]], " total associated truth values.")
print("Number of events with 2 truth values: ", len(double))
print("Total number of events with multiple truth values: ", len(double)+len(triple))

#To look at the whole list of event IDs and how many times they appear in the hdf file, uncomment the following line
#count
# Out:
# Number of events with more than 2 truth values:  1 with event ID:  [23431]
# The event:  [23431] has  3  total associated truth values.
# Number of events with 2 truth values:  289
# Total number of events with multiple truth values:  290

# %% [markdown]
# From the above code we can see that 289 events have 2 truth values, while one event has 3 truth values. Lets look more closely at the event with 3 truth values and see if we can find why it appears more than once.

# %%
#Want to find the index where the repeated event occurs. 
w = np.where(event_ids == triple[0])

for i in range(count[triple[0]]):
    print("Event ID: ", event_ids[w[0][i]], "with index: ", w[0][i], "and truth value: ", event_truths[w[0][i]])
# Out:
# Event ID:  23431 with index:  6203 and truth value:  11
# Event ID:  23431 with index:  6204 and truth value:  11
# Event ID:  23431 with index:  6205 and truth value:  11

# %% [markdown]
# We now have the index and truth value of this event. Lets look at the event header for these three events and see if there is any difference.

# %%
#Start by building a numpy array of the values stored within the event header. 
A = np.hstack((numu_21971_493_hdf['I3EventHeader'][w[0][0]],
              numu_21971_493_hdf['I3EventHeader'][w[0][1]],
              numu_21971_493_hdf['I3EventHeader'][w[0][2]]))

df = pd.DataFrame(data = A, columns = numu_21971_493_hdf['I3EventHeader'].dtype.names[0:9][:])

print("Sub Events have different I3EventHeader values for: ",\
     numu_21971_493_hdf['I3EventHeader'].dtype.names[5][:], "and: ",\
     numu_21971_493_hdf['I3EventHeader'].dtype.names[7][:])

df
# Out:
# Sub Events have different I3EventHeader values for:  time_start_utc_daq and:  time_end_utc_daq
#      Run  Event  SubEvent  SubEventStream  exists  time_start_utc_daq  \
# 0  21971  23431         0               0       1  130612472957056493
# 1  21971  23431         1               0       1  130612472957189393
# 2  21971  23431         2               0       1  130612472957349183
#
#    time_start_mjd    time_end_utc_daq  time_end_mjd
# 0    59000.171844  130612472957159653  59000.171844
# 1    59000.171844  130612472957308803  59000.171844
# 2    59000.171844  130612472957489083  59000.171844

# %% [markdown]
# The mystery of the multiple MC events is solved (for now)! It seems the repeated events come from different sub-events. I am unsure how significant the sub-events are and whether it is a good or bad idea to remove them.
#
# One way I can think to check is by looking at the truth values for the repeated events and if they all indeed have the same truth values. If they have the same truth values then it might imply that the events are the same enough to be recongized as identical truth/event pairs.

# %%
"""
Use list of all repeated events (list called duplicates) to get their index and find their truth values. 
The goal here is to produce the list of repeated events and each of their truth values to see if they 
repeated events have the same truths. 
"""

dup_index = [] #initialize empty list to store the indices of duplicate values. 
for k in range(len(duplicates)):
    dup_index.append(np.where(event_ids == duplicates[k]))

for l in range(len(dup_index)):
    for j in range(len(dup_index[l][0])):
        repeat_event_id = event_ids[dup_index[l][0][j]]
        repeat_index = dup_index[l][0][j]
        repeat_truths = event_truths[dup_index[l][0][j]]
        print("Event ID :", repeat_event_id, "with index: ", repeat_index, "and truth value: ", repeat_truths)
        
#Note: I can make new empty lists or new key/value pairs to store the output values in if needed.
# Out:
# Event ID : 270 with index:  61 and truth value:  1
# Event ID : 270 with index:  62 and truth value:  1
# Event ID : 305 with index:  72 and truth value:  2
# Event ID : 305 with index:  73 and truth value:  2
# Event ID : 378 with index:  87 and truth value:  101
# Event ID : 378 with index:  88 and truth value:  101
# Event ID : 489 with index:  111 and truth value:  4
# Event ID : 489 with index:  112 and truth value:  4
# Event ID : 578 with index:  142 and truth value:  2
# Event ID : 578 with index:  143 and truth value:  2
# Event ID : 670 with index:  158 and truth value:  11
# Event ID : 670 with index:  159 and truth value:  11
# Event ID : 995 with index:  247 and truth value:  101
# Event ID : 995 with index:  248 and truth value:  101
# Event ID : 1024 with index:  256 and truth value:  101
# Event ID : 1024 with index:  257 and truth value:  101
# Event ID : 1201 with index:  303 and truth value:  2
# Event ID : 1201 with index:  304 and truth value:  2
# Event ID : 1333 with index:  338 and truth value:  2
# Event ID : 1333 with index:  339 and truth value:  2
# Event ID : 1526 with index:  383 and truth value:  2
# Event ID : 1526 with index:  384 and truth value:  2
# Event ID : 1588 with index:  396 and truth value:  101
# Event ID : 1588 with index:  397 and truth value:  101
# Event ID : 1632 with index:  409 and truth value:  101
# Event ID : 1632 with index:  410 and truth value:  101
# Event ID : 1718 with index:  430 and truth value:  11
# Event ID : 1718 with index:  431 and truth value:  11
# Event ID : 1732 with index:  433 and truth value:  2
# Event ID : 1732 with index:  434 and truth value:  2
# Event ID : 1816 with index:  460 and truth value:  2
# Event ID : 1816 with index:  461 and truth value:  2
# Event ID : 1962 with index:  506 and truth value:  1
# Event ID : 1962 with index:  507 and truth value:  1
# Event ID : 2148 with index:  551 and truth value:  4
# Event ID : 2148 with index:  552 and truth value:  4
# Event ID : 2494 with index:  626 and truth value:  101
# Event ID : 2494 with index:  627 and truth value:  101
# Event ID : 2835 with index:  702 and truth value:  2
# Event ID : 2835 with index:  703 and truth value:  2
# Event ID : 2873 with index:  713 and truth value:  2
# Event ID : 2873 with index:  714 and truth value:  2
# Event ID : 2889 with index:  721 and truth value:  1
# Event ID : 2889 with index:  722 and truth value:  1
# Event ID : 2915 with index:  732 and truth value:  4
# Event ID : 2915 with index:  733 and truth value:  4
# Event ID : 2929 with index:  737 and truth value:  11
# Event ID : 2929 with index:  738 and truth value:  11
# Event ID : 2992 with index:  754 and truth value:  1
# Event ID : 2992 with index:  755 and truth value:  1
# Event ID : 2998 with index:  757 and truth value:  4
# Event ID : 2998 with index:  758 and truth value:  4
# Event ID : 3079 with index:  782 and truth value:  1
# Event ID : 3079 with index:  783 and truth value:  1
# Event ID : 3120 with index:  796 and truth value:  4
# Event ID : 3120 with index:  797 and truth value:  4
# Event ID : 3242 with index:  831 and truth value:  2
# Event ID : 3242 with index:  832 and truth value:  2
# Event ID : 3368 with index:  863 and truth value:  101
# Event ID : 3368 with index:  864 and truth value:  101
# Event ID : 3445 with index:  879 and truth value:  4
# Event ID : 3445 with index:  880 and truth value:  4
# Event ID : 3788 with index:  981 and truth value:  101
# Event ID : 3788 with index:  982 and truth value:  101
# Event ID : 4008 with index:  1035 and truth value:  2
# Event ID : 4008 with index:  1036 and truth value:  2
# Event ID : 4118 with index:  1059 and truth value:  101
# Event ID : 4118 with index:  1060 and truth value:  101
# Event ID : 4384 with index:  1130 and truth value:  4
# Event ID : 4384 with index:  1131 and truth value:  4
# Event ID : 4460 with index:  1155 and truth value:  101
# Event ID : 4460 with index:  1156 and truth value:  101
# Event ID : 4500 with index:  1169 and truth value:  4
# Event ID : 4500 with index:  1170 and truth value:  4
# Event ID : 4509 with index:  1174 and truth value:  4
# Event ID : 4509 with index:  1175 and truth value:  4
# Event ID : 4913 with index:  1262 and truth value:  4
# Event ID : 4913 with index:  1263 and truth value:  4
# Event ID : 4939 with index:  1273 and truth value:  0
# Event ID : 4939 with index:  1274 and truth value:  0
# Event ID : 4958 with index:  1280 and truth value:  101
# Event ID : 4958 with index:  1281 and truth value:  101
# Event ID : 5037 with index:  1303 and truth value:  4
# Event ID : 5037 with index:  1304 and truth value:  4
# Event ID : 5343 with index:  1379 and truth value:  101
# Event ID : 5343 with index:  1380 and truth value:  101
# Event ID : 5369 with index:  1387 and truth value:  4
# Event ID : 5369 with index:  1388 and truth value:  4
# Event ID : 5683 with index:  1459 and truth value:  4
# Event ID : 5683 with index:  1460 and truth value:  4
# Event ID : 5871 with index:  1518 and truth value:  101
# Event ID : 5871 with index:  1519 and truth value:  101
# Event ID : 6018 with index:  1564 and truth value:  101
# Event ID : 6018 with index:  1565 and truth value:  101
# Event ID : 6055 with index:  1579 and truth value:  4
# Event ID : 6055 with index:  1580 and truth value:  4
# Event ID : 6149 with index:  1606 and truth value:  1
# Event ID : 6149 with index:  1607 and truth value:  1
# Event ID : 6196 with index:  1622 and truth value:  101
# Event ID : 6196 with index:  1623 and truth value:  101
# Event ID : 6243 with index:  1635 and truth value:  101
# Event ID : 6243 with index:  1636 and truth value:  101
# Event ID : 6627 with index:  1740 and truth value:  101
# Event ID : 6627 with index:  1741 and truth value:  101
# Event ID : 6634 with index:  1742 and truth value:  2
# Event ID : 6634 with index:  1743 and truth value:  2
# Event ID : 6738 with index:  1765 and truth value:  101
# Event ID : 6738 with index:  1766 and truth value:  101
# Event ID : 6753 with index:  1772 and truth value:  4
# Event ID : 6753 with index:  1773 and truth value:  4
# Event ID : 6819 with index:  1792 and truth value:  1
# Event ID : 6819 with index:  1793 and truth value:  1
# Event ID : 6942 with index:  1821 and truth value:  101
# Event ID : 6942 with index:  1822 and truth value:  101
# Event ID : 6994 with index:  1832 and truth value:  2
# Event ID : 6994 with index:  1833 and truth value:  2
# Event ID : 7073 with index:  1853 and truth value:  1
# Event ID : 7073 with index:  1854 and truth value:  1
# Event ID : 7135 with index:  1870 and truth value:  2
# Event ID : 7135 with index:  1871 and truth value:  2
# Event ID : 7311 with index:  1920 and truth value:  2
# Event ID : 7311 with index:  1921 and truth value:  2
# Event ID : 7467 with index:  1957 and truth value:  1
# Event ID : 7467 with index:  1958 and truth value:  1
# Event ID : 7506 with index:  1964 and truth value:  1
# Event ID : 7506 with index:  1965 and truth value:  1
# Event ID : 7611 with index:  1991 and truth value:  4
# Event ID : 7611 with index:  1992 and truth value:  4
# Event ID : 7787 with index:  2038 and truth value:  2
# Event ID : 7787 with index:  2039 and truth value:  2
# Event ID : 8019 with index:  2102 and truth value:  2
# Event ID : 8019 with index:  2103 and truth value:  2
# Event ID : 8173 with index:  2137 and truth value:  2
# Event ID : 8173 with index:  2138 and truth value:  2
# Event ID : 8252 with index:  2154 and truth value:  4
# Event ID : 8252 with index:  2155 and truth value:  4
# Event ID : 8354 with index:  2189 and truth value:  4
# Event ID : 8354 with index:  2190 and truth value:  4
# Event ID : 8362 with index:  2192 and truth value:  2
# Event ID : 8362 with index:  2193 and truth value:  2
# Event ID : 8411 with index:  2207 and truth value:  4
# Event ID : 8411 with index:  2208 and truth value:  4
# Event ID : 8534 with index:  2236 and truth value:  101
# Event ID : 8534 with index:  2237 and truth value:  101
# Event ID : 8615 with index:  2258 and truth value:  101
# Event ID : 8615 with index:  2259 and truth value:  101
# Event ID : 8675 with index:  2276 and truth value:  4
# Event ID : 8675 with index:  2277 and truth value:  4
# Event ID : 8689 with index:  2282 and truth value:  101
# Event ID : 8689 with index:  2283 and truth value:  101
# Event ID : 8690 with index:  2284 and truth value:  4
# Event ID : 8690 with index:  2285 and truth value:  4
# Event ID : 8693 with index:  2286 and truth value:  4
# Event ID : 8693 with index:  2287 and truth value:  4
# Event ID : 8875 with index:  2339 and truth value:  4
# Event ID : 8875 with index:  2340 and truth value:  4
# Event ID : 8955 with index:  2363 and truth value:  2
# Event ID : 8955 with index:  2364 and truth value:  2
# Event ID : 9165 with index:  2413 and truth value:  1
# Event ID : 9165 with index:  2414 and truth value:  1
# Event ID : 9207 with index:  2425 and truth value:  101
# Event ID : 9207 with index:  2426 and truth value:  101
# Event ID : 9263 with index:  2442 and truth value:  2
# Event ID : 9263 with index:  2443 and truth value:  2
# Event ID : 9287 with index:  2450 and truth value:  4
# Event ID : 9287 with index:  2451 and truth value:  4
# Event ID : 9345 with index:  2466 and truth value:  101
# Event ID : 9345 with index:  2467 and truth value:  101
# Event ID : 9486 with index:  2509 and truth value:  2
# Event ID : 9486 with index:  2510 and truth value:  2
# Event ID : 9557 with index:  2525 and truth value:  11
# Event ID : 9557 with index:  2526 and truth value:  11
# Event ID : 9650 with index:  2548 and truth value:  2
# Event ID : 9650 with index:  2549 and truth value:  2
# Event ID : 9696 with index:  2562 and truth value:  101
# Event ID : 9696 with index:  2563 and truth value:  101
# Event ID : 9765 with index:  2583 and truth value:  2
# Event ID : 9765 with index:  2584 and truth value:  2
# Event ID : 9779 with index:  2588 and truth value:  1
# Event ID : 9779 with index:  2589 and truth value:  1
# Event ID : 9875 with index:  2613 and truth value:  101
# Event ID : 9875 with index:  2614 and truth value:  101
# Event ID : 9892 with index:  2618 and truth value:  101
# Event ID : 9892 with index:  2619 and truth value:  101
# Event ID : 9958 with index:  2632 and truth value:  101
# Event ID : 9958 with index:  2633 and truth value:  101
# Event ID : 10023 with index:  2654 and truth value:  2
# Event ID : 10023 with index:  2655 and truth value:  2
# Event ID : 10055 with index:  2662 and truth value:  4
# Event ID : 10055 with index:  2663 and truth value:  4
# Event ID : 10179 with index:  2690 and truth value:  2
# Event ID : 10179 with index:  2691 and truth value:  2
# Event ID : 10231 with index:  2710 and truth value:  4
# Event ID : 10231 with index:  2711 and truth value:  4
# Event ID : 10329 with index:  2732 and truth value:  2
# Event ID : 10329 with index:  2733 and truth value:  2
# Event ID : 10369 with index:  2740 and truth value:  1
# Event ID : 10369 with index:  2741 and truth value:  1
# Event ID : 10494 with index:  2775 and truth value:  4
# Event ID : 10494 with index:  2776 and truth value:  4
# Event ID : 10612 with index:  2812 and truth value:  1
# Event ID : 10612 with index:  2813 and truth value:  1
# Event ID : 10731 with index:  2844 and truth value:  11
# Event ID : 10731 with index:  2845 and truth value:  11
# Event ID : 10821 with index:  2866 and truth value:  2
# Event ID : 10821 with index:  2867 and truth value:  2
# Event ID : 10839 with index:  2872 and truth value:  2
# Event ID : 10839 with index:  2873 and truth value:  2
# Event ID : 10864 with index:  2881 and truth value:  1
# Event ID : 10864 with index:  2882 and truth value:  1
# Event ID : 11408 with index:  3009 and truth value:  101
# Event ID : 11408 with index:  3010 and truth value:  101
# Event ID : 11460 with index:  3027 and truth value:  101
# Event ID : 11460 with index:  3028 and truth value:  101
# Event ID : 11507 with index:  3035 and truth value:  2
# Event ID : 11507 with index:  3036 and truth value:  2
# Event ID : 11616 with index:  3062 and truth value:  2
# Event ID : 11616 with index:  3063 and truth value:  2
# Event ID : 11701 with index:  3091 and truth value:  101
# Event ID : 11701 with index:  3092 and truth value:  101
# Event ID : 11792 with index:  3113 and truth value:  1
# Event ID : 11792 with index:  3114 and truth value:  1
# Event ID : 11828 with index:  3124 and truth value:  2
# Event ID : 11828 with index:  3125 and truth value:  2
# Event ID : 11906 with index:  3142 and truth value:  101
# Event ID : 11906 with index:  3143 and truth value:  101
# Event ID : 11946 with index:  3157 and truth value:  4
# Event ID : 11946 with index:  3158 and truth value:  4
# Event ID : 11952 with index:  3160 and truth value:  2
# Event ID : 11952 with index:  3161 and truth value:  2
# Event ID : 12065 with index:  3196 and truth value:  4
# Event ID : 12065 with index:  3197 and truth value:  4
# Event ID : 12072 with index:  3198 and truth value:  101
# Event ID : 12072 with index:  3199 and truth value:  101
# Event ID : 12293 with index:  3246 and truth value:  0
# Event ID : 12293 with index:  3247 and truth value:  0
# Event ID : 12294 with index:  3248 and truth value:  2
# Event ID : 12294 with index:  3249 and truth value:  2
# Event ID : 12421 with index:  3288 and truth value:  1
# Event ID : 12421 with index:  3289 and truth value:  1
# Event ID : 12577 with index:  3325 and truth value:  4
# Event ID : 12577 with index:  3326 and truth value:  4
# Event ID : 12637 with index:  3342 and truth value:  4
# Event ID : 12637 with index:  3343 and truth value:  4
# Event ID : 12738 with index:  3374 and truth value:  101
# Event ID : 12738 with index:  3375 and truth value:  101
# Event ID : 12803 with index:  3391 and truth value:  1
# Event ID : 12803 with index:  3392 and truth value:  1
# Event ID : 13141 with index:  3474 and truth value:  1
# Event ID : 13141 with index:  3475 and truth value:  1
# Event ID : 13211 with index:  3496 and truth value:  2
# Event ID : 13211 with index:  3497 and truth value:  2
# Event ID : 13265 with index:  3511 and truth value:  101
# Event ID : 13265 with index:  3512 and truth value:  101
# Event ID : 13372 with index:  3542 and truth value:  11
# Event ID : 13372 with index:  3543 and truth value:  11
# Event ID : 13399 with index:  3551 and truth value:  2
# Event ID : 13399 with index:  3552 and truth value:  2
# Event ID : 13486 with index:  3571 and truth value:  101
# Event ID : 13486 with index:  3572 and truth value:  101
# Event ID : 13517 with index:  3578 and truth value:  101
# Event ID : 13517 with index:  3579 and truth value:  101
# Event ID : 13533 with index:  3586 and truth value:  2
# Event ID : 13533 with index:  3587 and truth value:  2
# Event ID : 13861 with index:  3678 and truth value:  2
# Event ID : 13861 with index:  3679 and truth value:  2
# Event ID : 13950 with index:  3705 and truth value:  11
# Event ID : 13950 with index:  3706 and truth value:  11
# Event ID : 14104 with index:  3743 and truth value:  2
# Event ID : 14104 with index:  3744 and truth value:  2
# Event ID : 14249 with index:  3786 and truth value:  2
# Event ID : 14249 with index:  3787 and truth value:  2
# Event ID : 14651 with index:  3890 and truth value:  2
# Event ID : 14651 with index:  3891 and truth value:  2
# Event ID : 14691 with index:  3907 and truth value:  1
# Event ID : 14691 with index:  3908 and truth value:  1
# Event ID : 14911 with index:  3957 and truth value:  1
# Event ID : 14911 with index:  3958 and truth value:  1
# Event ID : 14934 with index:  3965 and truth value:  4
# Event ID : 14934 with index:  3966 and truth value:  4
# Event ID : 15082 with index:  4008 and truth value:  4
# Event ID : 15082 with index:  4009 and truth value:  4
# Event ID : 15086 with index:  4011 and truth value:  4
# Event ID : 15086 with index:  4012 and truth value:  4
# Event ID : 15246 with index:  4054 and truth value:  4
# Event ID : 15246 with index:  4055 and truth value:  4
# Event ID : 15313 with index:  4068 and truth value:  101
# Event ID : 15313 with index:  4069 and truth value:  101
# Event ID : 15450 with index:  4106 and truth value:  1
# Event ID : 15450 with index:  4107 and truth value:  1
# Event ID : 15564 with index:  4126 and truth value:  101
# Event ID : 15564 with index:  4127 and truth value:  101
# Event ID : 15565 with index:  4128 and truth value:  101
# Event ID : 15565 with index:  4129 and truth value:  101
# Event ID : 15694 with index:  4166 and truth value:  2
# Event ID : 15694 with index:  4167 and truth value:  2
# Event ID : 15756 with index:  4182 and truth value:  2
# Event ID : 15756 with index:  4183 and truth value:  2
# Event ID : 15757 with index:  4184 and truth value:  101
# Event ID : 15757 with index:  4185 and truth value:  101
# Event ID : 15793 with index:  4196 and truth value:  101
# Event ID : 15793 with index:  4197 and truth value:  101
# Event ID : 16143 with index:  4284 and truth value:  1
# Event ID : 16143 with index:  4285 and truth value:  1
# Event ID : 16157 with index:  4288 and truth value:  4
# Event ID : 16157 with index:  4289 and truth value:  4
# Event ID : 16535 with index:  4386 and truth value:  4
# Event ID : 16535 with index:  4387 and truth value:  4
# Event ID : 16637 with index:  4411 and truth value:  4
# Event ID : 16637 with index:  4412 and truth value:  4
# Event ID : 16818 with index:  4451 and truth value:  4
# Event ID : 16818 with index:  4452 and truth value:  4
# Event ID : 16871 with index:  4462 and truth value:  0
# Event ID : 16871 with index:  4463 and truth value:  0
# Event ID : 16963 with index:  4491 and truth value:  2
# Event ID : 16963 with index:  4492 and truth value:  2
# Event ID : 16975 with index:  4496 and truth value:  4
# Event ID : 16975 with index:  4497 and truth value:  4
# Event ID : 17066 with index:  4520 and truth value:  101
# Event ID : 17066 with index:  4521 and truth value:  101
# Event ID : 17279 with index:  4578 and truth value:  4
# Event ID : 17279 with index:  4579 and truth value:  4
# Event ID : 17284 with index:  4583 and truth value:  101
# Event ID : 17284 with index:  4584 and truth value:  101
# Event ID : 17441 with index:  4623 and truth value:  4
# Event ID : 17441 with index:  4624 and truth value:  4
# Event ID : 17568 with index:  4655 and truth value:  2
# Event ID : 17568 with index:  4656 and truth value:  2
# Event ID : 17613 with index:  4672 and truth value:  1
# Event ID : 17613 with index:  4673 and truth value:  1
# Event ID : 17640 with index:  4681 and truth value:  4
# Event ID : 17640 with index:  4682 and truth value:  4
# Event ID : 17899 with index:  4744 and truth value:  101
# Event ID : 17899 with index:  4745 and truth value:  101
# Event ID : 18058 with index:  4787 and truth value:  1
# Event ID : 18058 with index:  4788 and truth value:  1
# Event ID : 18148 with index:  4809 and truth value:  101
# Event ID : 18148 with index:  4810 and truth value:  101
# Event ID : 18366 with index:  4865 and truth value:  101
# Event ID : 18366 with index:  4866 and truth value:  101
# Event ID : 18496 with index:  4904 and truth value:  4
# Event ID : 18496 with index:  4905 and truth value:  4
# Event ID : 18650 with index:  4950 and truth value:  1
# Event ID : 18650 with index:  4951 and truth value:  1
# Event ID : 18782 with index:  4984 and truth value:  2
# Event ID : 18782 with index:  4985 and truth value:  2
# Event ID : 19107 with index:  5068 and truth value:  2
# Event ID : 19107 with index:  5069 and truth value:  2
# Event ID : 19112 with index:  5071 and truth value:  101
# Event ID : 19112 with index:  5072 and truth value:  101
# Event ID : 19186 with index:  5087 and truth value:  2
# Event ID : 19186 with index:  5088 and truth value:  2
# Event ID : 19502 with index:  5165 and truth value:  2
# Event ID : 19502 with index:  5166 and truth value:  2
# Event ID : 19863 with index:  5253 and truth value:  2
# Event ID : 19863 with index:  5254 and truth value:  2
# Event ID : 20094 with index:  5322 and truth value:  2
# Event ID : 20094 with index:  5323 and truth value:  2
# Event ID : 20232 with index:  5362 and truth value:  101
# Event ID : 20232 with index:  5363 and truth value:  101
# Event ID : 20268 with index:  5371 and truth value:  4
# Event ID : 20268 with index:  5372 and truth value:  4
# Event ID : 20537 with index:  5443 and truth value:  4
# Event ID : 20537 with index:  5444 and truth value:  4
# Event ID : 20566 with index:  5452 and truth value:  4
# Event ID : 20566 with index:  5453 and truth value:  4
# Event ID : 20600 with index:  5463 and truth value:  2
# Event ID : 20600 with index:  5464 and truth value:  2
# Event ID : 20766 with index:  5510 and truth value:  101
# Event ID : 20766 with index:  5511 and truth value:  101
# Event ID : 20798 with index:  5518 and truth value:  4
# Event ID : 20798 with index:  5519 and truth value:  4
# Event ID : 20877 with index:  5535 and truth value:  4
# Event ID : 20877 with index:  5536 and truth value:  4
# Event ID : 21140 with index:  5606 and truth value:  11
# Event ID : 21140 with index:  5607 and truth value:  11
# Event ID : 21216 with index:  5628 and truth value:  101
# Event ID : 21216 with index:  5629 and truth value:  101
# Event ID : 21563 with index:  5721 and truth value:  101
# Event ID : 21563 with index:  5722 and truth value:  101
# Event ID : 21569 with index:  5723 and truth value:  1
# Event ID : 21569 with index:  5724 and truth value:  1
# Event ID : 21681 with index:  5749 and truth value:  11
# Event ID : 21681 with index:  5750 and truth value:  11
# Event ID : 22034 with index:  5833 and truth value:  1
# Event ID : 22034 with index:  5834 and truth value:  1
# Event ID : 22256 with index:  5896 and truth value:  4
# Event ID : 22256 with index:  5897 and truth value:  4
# Event ID : 22361 with index:  5923 and truth value:  4
# Event ID : 22361 with index:  5924 and truth value:  4
# Event ID : 22503 with index:  5956 and truth value:  4
# Event ID : 22503 with index:  5957 and truth value:  4
# Event ID : 22551 with index:  5972 and truth value:  2
# Event ID : 22551 with index:  5973 and truth value:  2
# Event ID : 22557 with index:  5975 and truth value:  4
# Event ID : 22557 with index:  5976 and truth value:  4
# Event ID : 22647 with index:  5996 and truth value:  1
# Event ID : 22647 with index:  5997 and truth value:  1
# Event ID : 22667 with index:  6003 and truth value:  2
# Event ID : 22667 with index:  6004 and truth value:  2
# Event ID : 22683 with index:  6009 and truth value:  1
# Event ID : 22683 with index:  6010 and truth value:  1
# Event ID : 22749 with index:  6027 and truth value:  101
# Event ID : 22749 with index:  6028 and truth value:  101
# Event ID : 22980 with index:  6079 and truth value:  101
# Event ID : 22980 with index:  6080 and truth value:  101
# Event ID : 23008 with index:  6090 and truth value:  1
# Event ID : 23008 with index:  6091 and truth value:  1
# Event ID : 23232 with index:  6151 and truth value:  1
# Event ID : 23232 with index:  6152 and truth value:  1
# Event ID : 23323 with index:  6174 and truth value:  1
# Event ID : 23323 with index:  6175 and truth value:  1
# Event ID : 23367 with index:  6187 and truth value:  2
# Event ID : 23367 with index:  6188 and truth value:  2
# Event ID : 23431 with index:  6203 and truth value:  11
# Event ID : 23431 with index:  6204 and truth value:  11
# Event ID : 23431 with index:  6205 and truth value:  11
# Event ID : 23431 with index:  6203 and truth value:  11
# Event ID : 23431 with index:  6204 and truth value:  11
# Event ID : 23431 with index:  6205 and truth value:  11
# Event ID : 23486 with index:  6223 and truth value:  4
# Event ID : 23486 with index:  6224 and truth value:  4
# Event ID : 23602 with index:  6251 and truth value:  2
# Event ID : 23602 with index:  6252 and truth value:  2
# Event ID : 23683 with index:  6282 and truth value:  4
# Event ID : 23683 with index:  6283 and truth value:  4
# Event ID : 23844 with index:  6321 and truth value:  4
# Event ID : 23844 with index:  6322 and truth value:  4
# Event ID : 23895 with index:  6331 and truth value:  101
# Event ID : 23895 with index:  6332 and truth value:  101
# Event ID : 24090 with index:  6380 and truth value:  1
# Event ID : 24090 with index:  6381 and truth value:  1
# Event ID : 24214 with index:  6412 and truth value:  101
# Event ID : 24214 with index:  6413 and truth value:  101
# Event ID : 24451 with index:  6478 and truth value:  101
# Event ID : 24451 with index:  6479 and truth value:  101
# Event ID : 24484 with index:  6490 and truth value:  4
# Event ID : 24484 with index:  6491 and truth value:  4
# Event ID : 24551 with index:  6508 and truth value:  2
# Event ID : 24551 with index:  6509 and truth value:  2
# Event ID : 24687 with index:  6545 and truth value:  4
# Event ID : 24687 with index:  6546 and truth value:  4
# Event ID : 24750 with index:  6563 and truth value:  101
# Event ID : 24750 with index:  6564 and truth value:  101
# Event ID : 24785 with index:  6576 and truth value:  11
# Event ID : 24785 with index:  6577 and truth value:  11
# Event ID : 24850 with index:  6592 and truth value:  101
# Event ID : 24850 with index:  6593 and truth value:  101
# Event ID : 25130 with index:  6658 and truth value:  101
# Event ID : 25130 with index:  6659 and truth value:  101
# Event ID : 25379 with index:  6724 and truth value:  4
# Event ID : 25379 with index:  6725 and truth value:  4
# Event ID : 25426 with index:  6740 and truth value:  101
# Event ID : 25426 with index:  6741 and truth value:  101
# Event ID : 25437 with index:  6746 and truth value:  4
# Event ID : 25437 with index:  6747 and truth value:  4
# Event ID : 25466 with index:  6755 and truth value:  4
# Event ID : 25466 with index:  6756 and truth value:  4
# Event ID : 25928 with index:  6878 and truth value:  4
# Event ID : 25928 with index:  6879 and truth value:  4
# Event ID : 25960 with index:  6891 and truth value:  1
# Event ID : 25960 with index:  6892 and truth value:  1
# Event ID : 26137 with index:  6939 and truth value:  101
# Event ID : 26137 with index:  6940 and truth value:  101
# Event ID : 26190 with index:  6952 and truth value:  2
# Event ID : 26190 with index:  6953 and truth value:  2
# Event ID : 26218 with index:  6959 and truth value:  2
# Event ID : 26218 with index:  6960 and truth value:  2
# Event ID : 26237 with index:  6966 and truth value:  101
# Event ID : 26237 with index:  6967 and truth value:  101
# Event ID : 26365 with index:  7007 and truth value:  1
# Event ID : 26365 with index:  7008 and truth value:  1
# Event ID : 26917 with index:  7144 and truth value:  4
# Event ID : 26917 with index:  7145 and truth value:  4
# Event ID : 26967 with index:  7158 and truth value:  101
# Event ID : 26967 with index:  7159 and truth value:  101
# Event ID : 27012 with index:  7171 and truth value:  2
# Event ID : 27012 with index:  7172 and truth value:  2
# Event ID : 27096 with index:  7189 and truth value:  101
# Event ID : 27096 with index:  7190 and truth value:  101
# Event ID : 27126 with index:  7196 and truth value:  1
# Event ID : 27126 with index:  7197 and truth value:  1
# Event ID : 27225 with index:  7231 and truth value:  4
# Event ID : 27225 with index:  7232 and truth value:  4
# Event ID : 27415 with index:  7273 and truth value:  4
# Event ID : 27415 with index:  7274 and truth value:  4
# Event ID : 27666 with index:  7343 and truth value:  4
# Event ID : 27666 with index:  7344 and truth value:  4
# Event ID : 27680 with index:  7349 and truth value:  4
# Event ID : 27680 with index:  7350 and truth value:  4
# Event ID : 27997 with index:  7429 and truth value:  2
# Event ID : 27997 with index:  7430 and truth value:  2
# Event ID : 28023 with index:  7436 and truth value:  1
# Event ID : 28023 with index:  7437 and truth value:  1
# Event ID : 28038 with index:  7441 and truth value:  101
# Event ID : 28038 with index:  7442 and truth value:  101
# Event ID : 28417 with index:  7551 and truth value:  4
# Event ID : 28417 with index:  7552 and truth value:  4
# Event ID : 28442 with index:  7557 and truth value:  4
# Event ID : 28442 with index:  7558 and truth value:  4
# Event ID : 28586 with index:  7594 and truth value:  2
# Event ID : 28586 with index:  7595 and truth value:  2
# Event ID : 28630 with index:  7609 and truth value:  2
# Event ID : 28630 with index:  7610 and truth value:  2
# Event ID : 28677 with index:  7621 and truth value:  101
# Event ID : 28677 with index:  7622 and truth value:  101
# Event ID : 28719 with index:  7639 and truth value:  11
# Event ID : 28719 with index:  7640 and truth value:  11
# Event ID : 28878 with index:  7683 and truth value:  4
# Event ID : 28878 with index:  7684 and truth value:  4
# Event ID : 29077 with index:  7734 and truth value:  4
# Event ID : 29077 with index:  7735 and truth value:  4
# Event ID : 29123 with index:  7744 and truth value:  4
# Event ID : 29123 with index:  7745 and truth value:  4
# Event ID : 29141 with index:  7753 and truth value:  4
# Event ID : 29141 with index:  7754 and truth value:  4
# Event ID : 29172 with index:  7763 and truth value:  101
# Event ID : 29172 with index:  7764 and truth value:  101
# Event ID : 29238 with index:  7790 and truth value:  2
# Event ID : 29238 with index:  7791 and truth value:  2
# Event ID : 29271 with index:  7802 and truth value:  1
# Event ID : 29271 with index:  7803 and truth value:  1
# Event ID : 29338 with index:  7822 and truth value:  4
# Event ID : 29338 with index:  7823 and truth value:  4
# Event ID : 29352 with index:  7829 and truth value:  11
# Event ID : 29352 with index:  7830 and truth value:  11
# Event ID : 29499 with index:  7868 and truth value:  4
# Event ID : 29499 with index:  7869 and truth value:  4
# Event ID : 29540 with index:  7877 and truth value:  11
# Event ID : 29540 with index:  7878 and truth value:  11
# Event ID : 29627 with index:  7900 and truth value:  4
# Event ID : 29627 with index:  7901 and truth value:  4
# Event ID : 29754 with index:  7934 and truth value:  2
# Event ID : 29754 with index:  7935 and truth value:  2
# Event ID : 29940 with index:  7981 and truth value:  11
# Event ID : 29940 with index:  7982 and truth value:  11
# Event ID : 29981 with index:  7987 and truth value:  1
# Event ID : 29981 with index:  7988 and truth value:  1
# Event ID : 30182 with index:  8029 and truth value:  4
# Event ID : 30182 with index:  8030 and truth value:  4
# Event ID : 30539 with index:  8115 and truth value:  4
# Event ID : 30539 with index:  8116 and truth value:  4
# Event ID : 30545 with index:  8119 and truth value:  4
# Event ID : 30545 with index:  8120 and truth value:  4
# Event ID : 30680 with index:  8153 and truth value:  1
# Event ID : 30680 with index:  8154 and truth value:  1
# Event ID : 30736 with index:  8168 and truth value:  4
# Event ID : 30736 with index:  8169 and truth value:  4
# Event ID : 30837 with index:  8192 and truth value:  101
# Event ID : 30837 with index:  8193 and truth value:  101
# Event ID : 30879 with index:  8203 and truth value:  4
# Event ID : 30879 with index:  8204 and truth value:  4
# Event ID : 30896 with index:  8208 and truth value:  2
# Event ID : 30896 with index:  8209 and truth value:  2
# Event ID : 30933 with index:  8218 and truth value:  1
# Event ID : 30933 with index:  8219 and truth value:  1
# Event ID : 30995 with index:  8233 and truth value:  101
# Event ID : 30995 with index:  8234 and truth value:  101
# Event ID : 31031 with index:  8243 and truth value:  4
# Event ID : 31031 with index:  8244 and truth value:  4
# Event ID : 31042 with index:  8248 and truth value:  101
# Event ID : 31042 with index:  8249 and truth value:  101
# Event ID : 31142 with index:  8270 and truth value:  4
# Event ID : 31142 with index:  8271 and truth value:  4
# Event ID : 31319 with index:  8316 and truth value:  4
# Event ID : 31319 with index:  8317 and truth value:  4
# Event ID : 31348 with index:  8321 and truth value:  4
# Event ID : 31348 with index:  8322 and truth value:  4
# Event ID : 31483 with index:  8359 and truth value:  4
# Event ID : 31483 with index:  8360 and truth value:  4
# Event ID : 31530 with index:  8375 and truth value:  4
# Event ID : 31530 with index:  8376 and truth value:  4
# Event ID : 31535 with index:  8377 and truth value:  4
# Event ID : 31535 with index:  8378 and truth value:  4
# Event ID : 31538 with index:  8380 and truth value:  4
# Event ID : 31538 with index:  8381 and truth value:  4
# Event ID : 31717 with index:  8417 and truth value:  4
# Event ID : 31717 with index:  8418 and truth value:  4
# Event ID : 32031 with index:  8507 and truth value:  11
# Event ID : 32031 with index:  8508 and truth value:  11
# Event ID : 32084 with index:  8516 and truth value:  4
# Event ID : 32084 with index:  8517 and truth value:  4

# %% [markdown]
# From just looking by eye it seems like each group of repeated events have the same truth values which makes me think that getting rid of the repeats wouldn't matter. But this might change depending on if the pulse series (InIceDSTPulse) or the values of another key (like the MC tree and its children) matter.
